# %%
# Experiment 5 : Introduction To dictionary
# Naman Bothra
# PRN : 25070123078

# Creation of dictionary
dict = {
    "Brand" : "Ford", "Model" : "Mustang", "Year" : 1964
}
print(dict)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964}

# %%
# Retreiving values from dictionary
dict = {
    "Brand" : "Ford", "Model" : "Mustang", "Year" : 1964
}
print(dict2["Year"])
# Out:
# 2020

# %%
#Dictionary takes the latest value give for any key : it does not allow duplicates
dict = {
    "Brand" : "Ford", "Model" : "Mustang", "Year" : 1964, "Year" : 2020
}
print(dict2["Year"])
# length of dictionary
print(len(dict))
# Out:
# 2020
# 3

# %%
# Changing/adding key:value in dictionnary
car = {
    "Brand" : "Ford", "Model" : "Mustang", "Year" : 1964,
}
car["color"] = "red"
print(car)
x = car.values()
print(x) #after the change
print(type(car))
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 1964, 'color': 'red'}
# dict_values(['Ford', 'Mustang', 1964, 'red'])
# <class 'dict'>

# %%
# retrival of values
student = {

    "roll" : 101, "name" : "Naman", "branch" : "ENTC"
}
student.pop("branch")
print("After removal:",student)
# Out:
# After removal: {'roll': 101, 'name': 'Naman'}

# %%
# Write a python program to update the price of a given product

products = {
    "pen" : 10, "book" : 70, "scale" : 10
    }
print(products)
    # after update
products["pen"] = 15
print(products)
# Out:
# {'pen': 10, 'book': 70, 'scale': 10}
# {'pen': 15, 'book': 70, 'scale': 10}

# %%
# write a python program to search for students marks
marks = {"A": 85, "B": 72, "C": 68}
name = input("Enter the name of the student: ")
print(marks.get(name, "Student not found"))
# Out:
# Enter the name of the student: D
# Student not found

# %%
# Write a python to to validate the user login
user = {
    "admin" : '1234', "student": "abcd"
}
username = input("Enter the username: ")
password = input("Enter the password: ")
if user.get(username) == password:
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter the username: admin
# Enter the password: abcd
# Login Failed

# %%
# write a python to find out the maximum marks
marks = {"A": 85, "B": 72, "C": 68}
topper = max(marks, key=marks.get)
print(topper)
# Out:
# A
